# %% [markdown]
# # Attempt to compare the original lotka-voltera equations with a discrte and binomial birth one

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.ndimage as ndi
from random import random
import matplotlib
from netCDF4 import Dataset
import matplotlib.cm as cm
import matplotlib.pyplot as plt    # The code below assumes this convenient renaming
import math
import seaborn as sns
sns.set()

import sys 
import pandas as pd

from binomial_function_collection import *

# %% [markdown]
# # modifying my original predator prey setup to act more like a discrete lotka voltera system

# %%
def func_timestepping_lotvol(N,a,b,c,d):
    """
    Runs timestepping, but needs everything to have already been defined previously in the settings cell.
    
    Mimics a very crude version of the predator prey model, where small objects (rabbits) are spawned randomly, but the more accumulate the higher the chance is of attracting a big objects (wolves) that eat a rabbit each time. 
    
    To sort out the order: 
    
    1. Object birthdays
    2. Births!
    3. Apply births
    4. Eat and starve as should be
    
    Has discrete death (through demographics)
    """
    #--- time loop ----
    for t in range(1,ntim):
        #print('timestep start:',t,', rabbits:',np.sum(N[:,:,0,t,:]),', wolfs:',np.sum(N[:,:,1,t,:]))

                
        #--- Object birthdays! Time-shift of the demographics levels ---
        for l in range(2):
            if t>0:
                for i in range(nage-1,0,-1):
                    #print("t=%s  l:%s  i:%s  max N:%s" % (t, l, i, np.max(N[:,:,l,t-1,i])) )
                    N[:,:,l,t,i] = N[:,:,l,t-1,i-1]   #note: oldest level is forgotten
            else:
                #
                print('no ageing first timestep')
                #N[:,:,l,0,1] = N[:,:,l,0,0]   #note: bodge for dealine with how I set the initial conditions
        
        #print('timestep post aging:',t,', rabbits:',np.sum(N[:,:,0,t,:]),', wolfs:',np.sum(N[:,:,1,t,:]))
        #print('rabbits post age:',N[0,0,0,0,:])
        #print('rabbits post age:',N[0,0,0,1,:])
        
        #--- Determine wolf birthrate, 
        #Wolf birthrate analystical
        wolf_birth_grid = d*b*np.sum(N[:,:,0,t,:],axis=2).ravel() * np.sum(N[:,:,1,t,:],axis=2).ravel() 
        #total births on ref domain
        wolf_birth_total_ref = ((wolf_birth_grid*L_ref*L_ref/dx/dy)*dtim).astype(int)
        N_tot_ref[:,:,1] = wolf_birth_total_ref.reshape([nx,ny])
        
        #--- Determine rabbit birthrate, 
        #Rabbit birthrate analystical
        rabbit_birth_grid = a*np.sum(N[:,:,0,t,:],axis=2).ravel() 
        #total births on ref domain
        rabbit_birth_total_ref = ((rabbit_birth_grid*L_ref*L_ref/dx/dy)*dtim).astype(int)
        N_tot_ref[:,:,0] = rabbit_birth_total_ref.reshape([nx,ny])
        
        #print('min new rabbit:',np.min(N_tot_ref[:,:,0]),'min new wolf:',np.min(N_tot_ref[:,:,1]))
        #print('min rabbit:',np.min(np.sum(N[:,:,0,t,:],axis=2).ravel()))
        if np.min(N_tot_ref[:,:,0])<0:
            print(N_tot_ref,a,N[:,:,0,t,:])
        #wolf_birth = np.sum(N[:,:,0,t,:],axis=2).ravel() * p[:,:,0,t].ravel()*ratio_birth
        #wolf_birth[np.where(wolf_birth>1)[0]]=0.99
        #wolf_birth[np.where(wolf_birth<0)[0]]=0.
        #p[:,:,1,t] = wolf_birth.reshape([nx,ny])
        
        
        
        #--- Calculate and apply birhts for both species ---
        for l in range(2):

            
            #--- Births ---
            B = np.random.binomial(N_tot_ref[:,:,l].ravel(), p[:,:,l,t].ravel(), nx*ny)
            B = B.reshape([nx,ny])
            # Warning! Need to make sure that the resizing is done correctly, so that x and y aren't swapped accidentally
            #if l ==0:
            #    print('rabbits born = ',np.sum(B))
            #if l ==1:
            #    print('wolfs born = ',np.sum(B))
            
            #--- Update object number: add births as level 1 demographics ---
            #print('births for size l:',l,B)
            N[:,:,l,t,0] = B   # add births 
            
        #print('timestep post birth:',t,', rabbits:',np.sum(N[:,:,0,t,:]),', wolfs:',np.sum(N[:,:,1,t,:]))
        
        
        
        
        
        
        
        #--- predation, this is a bit trickier than birth ---
        #rabbit eaten analytical
        rabbit_eaten_grid = b*np.sum(N[:,:,0,t,:],axis=2).ravel() * np.sum(N[:,:,1,t,:],axis=2).ravel() 
        #rabbit eaten discrete on ref domain
        rabbit_eaten_ref_total =  ((rabbit_eaten_grid*L_ref*L_ref/dx/dy)*dtim).astype(int)
        #Cacluating rabits eaten on each grid cell using binomial trial
        rabbits_eaten = (np.random.binomial(rabbit_eaten_ref_total.ravel(), p[:,:,l,t].ravel(), nx*ny)).reshape([nx,ny])
        
        #rabbits_eaten     = np.sum(N[:,:,1,t,:],axis=2)
        #diff_wolf_rabbits = np.sum(N[:,:,1,t,:],axis=2)-np.sum(N[:,:,0,t,:],axis=2)
        
        #Ok, I am struggling to make this work nicely, so for now I will do it box by box, and will make it nice later
            
        for i in range(nx):
            for j in range(ny):
                #--- Update object number: remove each eaten rabbit from a random age group ---
            
                for w in range(rabbits_eaten[i,j]):
                    total_rabbits_now = np.sum(N[i,j,0,t,:])
                    if total_rabbits_now>0:
                        #randomly select the rabbit to die
                        dead_wabbit = np.random.randint(total_rabbits_now)+1 
                        #use searchsorted and cumsum to check which rabbit was eaten
                        age_dead_wabbit = np.searchsorted(np.cumsum(N[i,j,0,t,:]),dead_wabbit)
                         
                        #revomve rabbit
                        N[i,j,0,t,age_dead_wabbit] -= 1
                        if N[i,j,0,t,age_dead_wabbit] <0:
                            print('here is where things go wrong')
                            print(np.cumsum(N[i,j,0,t,:]))
                            print(total_rabbits_now,dead_wabbit,age_dead_wabbit,rabbits_eaten[i,j],N[i,j,0,t,:])
                            print(not_defined)
                        
          
        #--- wolf deaths, also for now just assumed to be taken from a random age
        
        #wolfs died analytical
        wolf_dead_grid = c*np.sum(N[:,:,1,t,:],axis=2).ravel()  
        #rabbit eaten discrete on ref domain
        wolf_dead_ref_total =  ((wolf_dead_grid*L_ref*L_ref/dx/dy)*dtim).astype(int)
        #Cacluating rabits eaten on each grid cell using binomial trial
        wolfs_dead = (np.random.binomial(wolf_dead_ref_total.ravel(), p[:,:,l,t].ravel(), nx*ny)).reshape([nx,ny])
        
        
        #Ok, I am struggling to make this work nicely, so for now I will do it box by box, and will make it nice later
            
        for i in range(nx):
            for j in range(ny):
                #--- Update object number: remove each dead wolf from a random age group ---
            
                for w in range(wolfs_dead[i,j]):
                    total_wolfs_now = np.sum(N[i,j,1,t,:])
                    if total_wolfs_now>0:
                        #randomly select the wolf to die
                        dead_wolf = np.random.randint(total_wolfs_now)+1 
                        #use searchsorted and cumsum to check which wolf died
                        age_dead_wolf = np.searchsorted(np.cumsum(N[i,j,1,t,:]),dead_wolf)
                         
                        #revomve wolf
                        N[i,j,1,t,age_dead_wolf] -= 1
                        if N[i,j,1,t,age_dead_wolf] <0:
                            print('here is where things go wrong')
                            print(np.cumsum(N[i,j,0,t,:]))
                            print(not_defined)
        print('timestep:',t,', rabbits:',np.sum(N[:,:,0,t,:]),', wolfs:',np.sum(N[:,:,1,t,:]),', rabbits eaten:',np.sum(rabbits_eaten),' wolfs dead:',np.sum(wolfs_dead))
        print('timestep:',t,', new rabbits:',np.sum(N[:,:,0,t,0]),', new wolfs:',np.sum(N[:,:,1,t,0]))
    return N

# %%
#

#--- Grid parameters ----------
nx   = 36    #grid size
ny   = 1

nsiz = 2       #nr of sizes in spectrum

#ntim = 10     #nr of timesteps
ntim = 150   #nr of timesteps 

nage = 1        #dimension of thermal demographics: number of thermal age strata

dx   = 10.    #x gridspacing     [km]
dy   = 10.     #y gridspacing    [km]
dsiz = 10.    #width of size bin [km]
dtim = 1./10     #time increment    [d]

#--- Reference domain
L_ref    = 50.   #size of very large reference domain  [km]
dt_ref   = dtim       #timestep of very large ref domain    [s]

#--- birth and lifetime constants --------

tau_D     = dtim*ntim   #object life time  [m]
#tau_D     = 150.    #object life time  [m]
tau_D_dt  = int(tau_D/dtim) #object life time in timesteps []

nage = int(tau_D/dtim)   #demographics: number of object age strata


# #--- Advection parameters
# u  = 5. #x wind, used for advection [m/s]
# v  = 5. #y wind, used for advection [m/s]

#lotka voltera parameters, devided by 12:


a = 1.   
c = 1.5  
d = 0.75 

b = 0.03  

print('stationary conditons',  c/(d*b), a/b)


#--- declare arrays -----------
x    = ( np.array(range(nx  )) + 0.5) * dx
y    = ( np.array(range(ny  )) + 0.5) * dy
siz  = ( np.array(range(nsiz)) + 0.5) * dsiz
tim  = ( np.array(range(ntim)) + 0.5) * dtim

N        = np.zeros( (nx,ny,nsiz,ntim,nage) ).astype(int)    #array containing object number
p        = np.empty( (nx,ny,nsiz,ntim) )    #array containing object birth probability


#starting population size of wolfs and foxes
N[:,:,0,0,0]=64#50
N[:,:,1,0,0]=16#15

#--- binomial probability values -----------
N_tot_ref = np.zeros((nx,ny,nsiz)).astype(int)

prob_sub = dx*dy*dtim/(dt_ref*L_ref*L_ref)     #probability that one of N_tot_ref births happens in a gridbox
print( "prob_sub=%s" % (prob_sub) )

p[:,:,:,:] = prob_sub

np.random.seed(0)
# Out:
# stationary conditons 66.66666666666667 33.333333333333336
# prob_sub=0.04

# %%
N= func_timestepping_lotvol(N,a,b,c,d)
# Out:
# timestep: 1 , rabbits: 2424 , wolfs: 565 , rabbits eaten: 127  wolfs dead: 88
# timestep: 1 , new rabbits: 236 , new wolfs: 62
# timestep: 2 , rabbits: 2516 , wolfs: 545 , rabbits eaten: 137  wolfs dead: 112
# timestep: 2 , new rabbits: 213 , new wolfs: 78
# timestep: 3 , rabbits: 2613 , wolfs: 526 , rabbits eaten: 143  wolfs dead: 93
# timestep: 3 , new rabbits: 227 , new wolfs: 57
# timestep: 4 , rabbits: 2717 , wolfs: 514 , rabbits eaten: 150  wolfs dead: 88
# timestep: 4 , new rabbits: 244 , new wolfs: 66
# timestep: 5 , rabbits: 2808 , wolfs: 526 , rabbits eaten: 148  wolfs dead: 85
# timestep: 5 , new rabbits: 226 , new wolfs: 82
# timestep: 6 , rabbits: 2952 , wolfs: 520 , rabbits eaten: 133  wolfs dead: 99
# timestep: 6 , new rabbits: 263 , new wolfs: 80
# timestep: 7 , rabbits: 3103 , wolfs: 525 , rabbits eaten: 162  wolfs dead: 89
# timestep: 7 , new rabbits: 289 , new wolfs: 84
# timestep: 8 , rabbits: 3247 , wolfs: 540 , rabbits eaten: 176  wolfs dead: 96
# timestep: 8 , new rabbits: 300 , new wolfs: 92
# timestep: 9 , rabbits: 3404 , wolfs: 562 , rabbits eaten: 196  wolfs dead: 96
# timestep: 9 , new rabbits: 332 , new wolfs: 103
# timestep: 10 , rabbits: 3564 , wolfs: 593 , rabbits eaten: 189  wolfs dead: 90
# timestep: 10 , new rabbits: 326 , new wolfs: 107
# timestep: 11 , rabbits: 3707 , wolfs: 637 , rabbits eaten: 222  wolfs dead: 86
# timestep: 11 , new rabbits: 345 , new wolfs: 112
# timestep: 12 , rabbits: 3818 , wolfs: 679 , rabbits eaten: 248  wolfs dead: 100
# timestep: 12 , new rabbits: 344 , new wolfs: 122
# timestep: 13 , rabbits: 3952 , wolfs: 720 , rabbits eaten: 253  wolfs dead: 121
# timestep: 13 , new rabbits: 365 , new wolfs: 135
# timestep: 14 , rabbits: 4014 , wolfs: 767 , rabbits eaten: 308  wolfs dead: 127
# timestep: 14 , new rabbits: 350 , new wolfs: 142
# timestep: 15 , rabbits: 4042 , wolfs: 783 , rabbits eaten: 379  wolfs dead: 168
# timestep: 15 , new rabbits: 366 , new wolfs: 148
# timestep: 16 , rabbits: 4134 , wolfs: 824 , rabbits eaten: 347  wolfs dead: 146
# timestep: 16 , new rabbits: 412 , new wolfs: 158
# timestep: 17 , rabbits: 4170 , wolfs: 868 , rabbits eaten: 368  wolfs dead: 158
# timestep: 17 , new rabbits: 370 , new wolfs: 177
# timestep: 18 , rabbits: 4191 , wolfs: 921 , rabbits eaten: 379  wolfs dead: 161
# timestep: 18 , new rabbits: 370 , new wolfs: 181
# timestep: 19 , rabbits: 4142 , wolfs: 1034 , rabbits eaten: 427  wolfs dead: 150
# timestep: 19 , new rabbits: 345 , new wolfs: 232
# timestep: 20 , rabbits: 4052 , wolfs: 1093 , rabbits eaten: 505  wolfs dead: 192
# timestep: 20 , new rabbits: 370 , new wolfs: 213
# timestep: 21 , rabbits: 3990 , wolfs: 1158 , rabbits eaten: 488  wolfs dead: 191
# timestep: 21 , new rabbits: 372 , new wolfs: 222
# timestep: 22 , rabbits: 3863 , wolfs: 1188 , rabbits eaten: 483  wolfs dead: 242
# timestep: 22 , new rabbits: 316 , new wolfs: 222
# timestep: 23 , rabbits: 3745 , wolfs: 1213 , rabbits eaten: 496  wolfs dead: 214
# timestep: 23 , new rabbits: 339 , new wolfs: 200
# timestep: 24 , rabbits: 3605 , wolfs: 1268 , rabbits eaten: 494  wolfs dead: 222
# timestep: 24 , new rabbits: 311 , new wolfs: 240
# timestep: 25 , rabbits: 3441 , wolfs: 1313 , rabbits eaten: 517  wolfs dead: 216
# timestep: 25 , new rabbits: 311 , new wolfs: 219
# timestep: 26 , rabbits: 3297 , wolfs: 1345 , rabbits eaten: 525  wolfs dead: 237
# timestep: 26 , new rabbits: 338 , new wolfs: 232
# timestep: 27 , rabbits: 3171 , wolfs: 1360 , rabbits eaten: 443  wolfs dead: 228
# timestep: 27 , new rabbits: 279 , new wolfs: 211
# timestep: 28 , rabbits: 3112 , wolfs: 1366 , rabbits eaten: 405  wolfs dead: 219
# timestep: 28 , new rabbits: 303 , new wolfs: 193
# timestep: 29 , rabbits: 2974 , wolfs: 1348 , rabbits eaten: 447  wolfs dead: 253
# timestep: 29 , new rabbits: 272 , new wolfs: 199
# timestep: 30 , rabbits: 2858 , wolfs: 1360 , rabbits eaten: 404  wolfs dead: 215
# timestep: 30 , new rabbits: 251 , new wolfs: 199
# timestep: 31 , rabbits: 2751 , wolfs: 1350 , rabbits eaten: 383  wolfs dead: 218
# timestep: 31 , new rabbits: 241 , new wolfs: 182
# timestep: 32 , rabbits: 2615 , wolfs: 1339 , rabbits eaten: 405  wolfs dead: 215
# timestep: 32 , new rabbits: 233 , new wolfs: 176
# timestep: 33 , rabbits: 2537 , wolfs: 1258 , rabbits eaten: 327  wolfs dead: 242
# timestep: 33 , new rabbits: 223 , new wolfs: 138
# timestep: 34 , rabbits: 2484 , wolfs: 1237 , rabbits eaten: 327  wolfs dead: 219
# timestep: 34 , new rabbits: 238 , new wolfs: 166
# timestep: 35 , rabbits: 2447 , wolfs: 1196 , rabbits eaten: 296  wolfs dead: 212
# timestep: 35 , new rabbits: 236 , new wolfs: 136
# timestep: 36 , rabbits: 2423 , wolfs: 1138 , rabbits eaten: 277  wolfs dead: 213
# timestep: 36 , new rabbits: 227 , new wolfs: 132
# timestep: 37 , rabbits: 2386 , wolfs: 1097 , rabbits eaten: 267  wolfs dead: 207
# timestep: 37 , new rabbits: 211 , new wolfs: 136
# timestep: 38 , rabbits: 2404 , wolfs: 1052 , rabbits eaten: 238  wolfs dead: 188
# timestep: 38 , new rabbits: 230 , new wolfs: 123
# timestep: 39 , rabbits: 2403 , wolfs: 1014 , rabbits eaten: 251  wolfs dead: 175
# timestep: 39 , new rabbits: 232 , new wolfs: 124
# timestep: 40 , rabbits: 2333 , wolfs: 1017 , rabbits eaten: 293  wolfs dead: 169
# timestep: 40 , new rabbits: 191 , new wolfs: 147
# timestep: 41 , rabbits: 2315 , wolfs: 1011 , rabbits eaten: 267  wolfs dead: 150
# timestep: 41 , new rabbits: 224 , new wolfs: 124
# timestep: 42 , rabbits: 2280 , wolfs: 986 , rabbits eaten: 276  wolfs dead: 173
# timestep: 42 , new rabbits: 220 , new wolfs: 125
# timestep: 43 , rabbits: 2216 , wolfs: 956 , rabbits eaten: 292  wolfs dead: 199
# timestep: 43 , new rabbits: 191 , new wolfs: 141
# timestep: 44 , rabbits: 2161 , wolfs: 938 , rabbits eaten: 311  wolfs dead: 179
# timestep: 44 , new rabbits: 228 , new wolfs: 136
# timestep: 45 , rabbits: 2152 , wolfs: 895 , rabbits eaten: 222  wolfs dead: 157
# timestep: 45 , new rabbits: 192 , new wolfs: 97
# timestep: 46 , rabbits: 2130 , wolfs: 878 , rabbits eaten: 223  wolfs dead: 139
# timestep: 46 , new rabbits: 182 , new wolfs: 106
# timestep: 47 , rabbits: 2173 , wolfs: 872 , rabbits eaten: 194  wolfs dead: 133
# timestep: 47 , new rabbits: 214 , new wolfs: 103
# timestep: 48 , rabbits: 2177 , wolfs: 824 , rabbits eaten: 209  wolfs dead: 139
# timestep: 48 , new rabbits: 194 , new wolfs: 78
# timestep: 49 , rabbits: 2204 , wolfs: 777 , rabbits eaten: 174  wolfs dead: 146
# timestep: 49 , new rabbits: 186 , new wolfs: 86
# timestep: 50 , rabbits: 2252 , wolfs: 731 , rabbits eaten: 156  wolfs dead: 136
# timestep: 50 , new rabbits: 187 , new wolfs: 78
# timestep: 51 , rabbits: 2283 , wolfs: 702 , rabbits eaten: 183  wolfs dead: 127
# timestep: 51 , new rabbits: 202 , new wolfs: 80
# timestep: 52 , rabbits: 2312 , wolfs: 682 , rabbits eaten: 178  wolfs dead: 123
# timestep: 52 , new rabbits: 197 , new wolfs: 88
# timestep: 53 , rabbits: 2374 , wolfs: 646 , rabbits eaten: 180  wolfs dead: 117
# timestep: 53 , new rabbits: 224 , new wolfs: 64
# timestep: 54 , rabbits: 2466 , wolfs: 652 , rabbits eaten: 160  wolfs dead: 95
# timestep: 54 , new rabbits: 241 , new wolfs: 90
# timestep: 55 , rabbits: 2497 , wolfs: 649 , rabbits eaten: 208  wolfs dead: 103
# timestep: 55 , new rabbits: 219 , new wolfs: 80
# timestep: 56 , rabbits: 2554 , wolfs: 638 , rabbits eaten: 209  wolfs dead: 113
# timestep: 56 , new rabbits: 250 , new wolfs: 83
# timestep: 57 , rabbits: 2581 , wolfs: 632 , rabbits eaten: 223  wolfs dead: 119
# timestep: 57 , new rabbits: 239 , new wolfs: 101
# timestep: 58 , rabbits: 2592 , wolfs: 654 , rabbits eaten: 239  wolfs dead: 112
# timestep: 58 , new rabbits: 233 , new wolfs: 112
# timestep: 59 , rabbits: 2631 , wolfs: 686 , rabbits eaten: 215  wolfs dead: 96
# timestep: 59 , new rabbits: 241 , new wolfs: 118
# timestep: 60 , rabbits: 2655 , wolfs: 709 , rabbits eaten: 229  wolfs dead: 115
# timestep: 60 , new rabbits: 230 , new wolfs: 117
# timestep: 61 , rabbits: 2682 , wolfs: 690 , rabbits eaten: 207  wolfs dead: 151
# timestep: 61 , new rabbits: 209 , new wolfs: 116
# timestep: 62 , rabbits: 2752 , wolfs: 683 , rabbits eaten: 231  wolfs dead: 130
# timestep: 62 , new rabbits: 275 , new wolfs: 99
# timestep: 63 , rabbits: 2830 , wolfs: 645 , rabbits eaten: 199  wolfs dead: 152
# timestep: 63 , new rabbits: 257 , new wolfs: 96
# timestep: 64 , rabbits: 2906 , wolfs: 671 , rabbits eaten: 226  wolfs dead: 99
# timestep: 64 , new rabbits: 283 , new wolfs: 113
# timestep: 65 , rabbits: 2984 , wolfs: 685 , rabbits eaten: 212  wolfs dead: 100
# timestep: 65 , new rabbits: 272 , new wolfs: 94
# timestep: 66 , rabbits: 3034 , wolfs: 673 , rabbits eaten: 221  wolfs dead: 130
# timestep: 66 , new rabbits: 260 , new wolfs: 96
# timestep: 67 , rabbits: 3123 , wolfs: 667 , rabbits eaten: 206  wolfs dead: 129
# timestep: 67 , new rabbits: 272 , new wolfs: 109
# timestep: 68 , rabbits: 3219 , wolfs: 689 , rabbits eaten: 207  wolfs dead: 108
# timestep: 68 , new rabbits: 287 , new wolfs: 113
# timestep: 69 , rabbits: 3305 , wolfs: 712 , rabbits eaten: 227  wolfs dead: 116
# timestep: 69 , new rabbits: 290 , new wolfs: 123
# timestep: 70 , rabbits: 3354 , wolfs: 709 , rabbits eaten: 258  wolfs dead: 142
# timestep: 70 , new rabbits: 276 , new wolfs: 120
# timestep: 71 , rabbits: 3465 , wolfs: 725 , rabbits eaten: 246  wolfs dead: 119
# timestep: 71 , new rabbits: 336 , new wolfs: 116
# timestep: 72 , rabbits: 3534 , wolfs: 754 , rabbits eaten: 262  wolfs dead: 109
# timestep: 72 , new rabbits: 310 , new wolfs: 122
# timestep: 73 , rabbits: 3607 , wolfs: 765 , rabbits eaten: 291  wolfs dead: 134
# timestep: 73 , new rabbits: 342 , new wolfs: 124
# timestep: 74 , rabbits: 3652 , wolfs: 787 , rabbits eaten: 302  wolfs dead: 126
# timestep: 74 , new rabbits: 316 , new wolfs: 129
# timestep: 75 , rabbits: 3733 , wolfs: 827 , rabbits eaten: 302  wolfs dead: 134
# timestep: 75 , new rabbits: 355 , new wolfs: 152
# timestep: 76 , rabbits: 3746 , wolfs: 859 , rabbits eaten: 364  wolfs dead: 144
# timestep: 76 , new rabbits: 333 , new wolfs: 159
# timestep: 77 , rabbits: 3800 , wolfs: 884 , rabbits eaten: 347  wolfs dead: 154
# timestep: 77 , new rabbits: 353 , new wolfs: 152
# timestep: 78 , rabbits: 3779 , wolfs: 912 , rabbits eaten: 393  wolfs dead: 169
# timestep: 78 , new rabbits: 340 , new wolfs: 166
# timestep: 79 , rabbits: 3776 , wolfs: 948 , rabbits eaten: 398  wolfs dead: 179
# timestep: 79 , new rabbits: 354 , new wolfs: 175
# timestep: 80 , rabbits: 3823 , wolfs: 983 , rabbits eaten: 335  wolfs dead: 171
# timestep: 80 , new rabbits: 344 , new wolfs: 185
# timestep: 81 , rabbits: 3868 , wolfs: 986 , rabbits eaten: 304  wolfs dead: 159
# timestep: 81 , new rabbits: 322 , new wolfs: 137
# timestep: 82 , rabbits: 3999 , wolfs: 984 , rabbits eaten: 286  wolfs dead: 150
# timestep: 82 , new rabbits: 389 , new wolfs: 125
# timestep: 83 , rabbits: 4136 , wolfs: 958 , rabbits eaten: 237  wolfs dead: 158
# timestep: 83 , new rabbits: 348 , new wolfs: 109
# timestep: 84 , rabbits: 4274 , wolfs: 954 , rabbits eaten: 262  wolfs dead: 146
# timestep: 84 , new rabbits: 379 , new wolfs: 121
# timestep: 85 , rabbits: 4417 , wolfs: 966 , rabbits eaten: 277  wolfs dead: 154
# timestep: 85 , new rabbits: 392 , new wolfs: 139
# timestep: 86 , rabbits: 4561 , wolfs: 956 , rabbits eaten: 292  wolfs dead: 149
# timestep: 86 , new rabbits: 404 , new wolfs: 121
# timestep: 87 , rabbits: 4719 , wolfs: 965 , rabbits eaten: 288  wolfs dead: 137
# timestep: 87 , new rabbits: 417 , new wolfs: 133
# timestep: 88 , rabbits: 4900 , wolfs: 941 , rabbits eaten: 283  wolfs dead: 186
# timestep: 88 , new rabbits: 442 , new wolfs: 140
# timestep: 89 , rabbits: 5049 , wolfs: 938 , rabbits eaten: 319  wolfs dead: 172
# timestep: 89 , new rabbits: 445 , new wolfs: 146
# timestep: 90 , rabbits: 5230 , wolfs: 923 , rabbits eaten: 318  wolfs dead: 168
# timestep: 90 , new rabbits: 465 , new wolfs: 123
# timestep: 91 , rabbits: 5494 , wolfs: 910 , rabbits eaten: 235  wolfs dead: 145
# timestep: 91 , new rabbits: 476 , new wolfs: 114
# timestep: 92 , rabbits: 5737 , wolfs: 865 , rabbits eaten: 261  wolfs dead: 180
# timestep: 92 , new rabbits: 483 , new wolfs: 113
# timestep: 93 , rabbits: 6107 , wolfs: 840 , rabbits eaten: 260  wolfs dead: 153
# timestep: 93 , new rabbits: 604 , new wolfs: 111
# timestep: 94 , rabbits: 6498 , wolfs: 827 , rabbits eaten: 207  wolfs dead: 138
# timestep: 94 , new rabbits: 571 , new wolfs: 113
# timestep: 95 , rabbits: 6935 , wolfs: 829 , rabbits eaten: 206  wolfs dead: 144
# timestep: 95 , new rabbits: 621 , new wolfs: 125
# timestep: 96 , rabbits: 7390 , wolfs: 816 , rabbits eaten: 220  wolfs dead: 127
# timestep: 96 , new rabbits: 655 , new wolfs: 96
# timestep: 97 , rabbits: 7932 , wolfs: 771 , rabbits eaten: 211  wolfs dead: 143
# timestep: 97 , new rabbits: 736 , new wolfs: 78
# timestep: 98 , rabbits: 8514 , wolfs: 762 , rabbits eaten: 176  wolfs dead: 137
# timestep: 98 , new rabbits: 740 , new wolfs: 110
# timestep: 99 , rabbits: 9201 , wolfs: 736 , rabbits eaten: 163  wolfs dead: 124
# timestep: 99 , new rabbits: 841 , new wolfs: 87
# timestep: 100 , rabbits: 9942 , wolfs: 712 , rabbits eaten: 192  wolfs dead: 135
# timestep: 100 , new rabbits: 919 , new wolfs: 93
# timestep: 101 , rabbits: 10752 , wolfs: 686 , rabbits eaten: 200  wolfs dead: 133
# timestep: 101 , new rabbits: 992 , new wolfs: 89
# timestep: 102 , rabbits: 11723 , wolfs: 665 , rabbits eaten: 170  wolfs dead: 124
# timestep: 102 , new rabbits: 1132 , new wolfs: 87
# timestep: 103 , rabbits: 12709 , wolfs: 650 , rabbits eaten: 150  wolfs dead: 94
# timestep: 103 , new rabbits: 1120 , new wolfs: 62
# timestep: 104 , rabbits: 13798 , wolfs: 639 , rabbits eaten: 180  wolfs dead: 111
# timestep: 104 , new rabbits: 1252 , new wolfs: 87
# timestep: 105 , rabbits: 14997 , wolfs: 633 , rabbits eaten: 181  wolfs dead: 115
# timestep: 105 , new rabbits: 1369 , new wolfs: 92
# timestep: 106 , rabbits: 16210 , wolfs: 642 , rabbits eaten: 238  wolfs dead: 102
# timestep: 106 , new rabbits: 1430 , new wolfs: 101
# timestep: 107 , rabbits: 17535 , wolfs: 670 , rabbits eaten: 246  wolfs dead: 103
# timestep: 107 , new rabbits: 1549 , new wolfs: 120
# timestep: 108 , rabbits: 18997 , wolfs: 670 , rabbits eaten: 254  wolfs dead: 117
# timestep: 108 , new rabbits: 1696 , new wolfs: 101
# timestep: 109 , rabbits: 20659 , wolfs: 680 , rabbits eaten: 194  wolfs dead: 101
# timestep: 109 , new rabbits: 1845 , new wolfs: 97
# timestep: 110 , rabbits: 22532 , wolfs: 706 , rabbits eaten: 230  wolfs dead: 103
# timestep: 110 , new rabbits: 2081 , new wolfs: 112
# timestep: 111 , rabbits: 24541 , wolfs: 704 , rabbits eaten: 243  wolfs dead: 143
# timestep: 111 , new rabbits: 2224 , new wolfs: 118
# timestep: 112 , rabbits: 26691 , wolfs: 723 , rabbits eaten: 263  wolfs dead: 122
# timestep: 112 , new rabbits: 2395 , new wolfs: 120
# timestep: 113 , rabbits: 29138 , wolfs: 741 , rabbits eaten: 242  wolfs dead: 118
# timestep: 113 , new rabbits: 2673 , new wolfs: 119
# timestep: 114 , rabbits: 31774 , wolfs: 737 , rabbits eaten: 259  wolfs dead: 151
# timestep: 114 , new rabbits: 2884 , new wolfs: 124
# timestep: 115 , rabbits: 34854 , wolfs: 729 , rabbits eaten: 225  wolfs dead: 135
# timestep: 115 , new rabbits: 3286 , new wolfs: 112
# timestep: 116 , rabbits: 38121 , wolfs: 720 , rabbits eaten: 219  wolfs dead: 148
# timestep: 116 , new rabbits: 3470 , new wolfs: 111
# timestep: 117 , rabbits: 41726 , wolfs: 698 , rabbits eaten: 180  wolfs dead: 130
# timestep: 117 , new rabbits: 3770 , new wolfs: 90
# timestep: 118 , rabbits: 45681 , wolfs: 687 , rabbits eaten: 174  wolfs dead: 114
# timestep: 118 , new rabbits: 4114 , new wolfs: 90
# timestep: 119 , rabbits: 50030 , wolfs: 671 , rabbits eaten: 198  wolfs dead: 115
# timestep: 119 , new rabbits: 4536 , new wolfs: 82
# timestep: 120 , rabbits: 54733 , wolfs: 667 , rabbits eaten: 213  wolfs dead: 121
# timestep: 120 , new rabbits: 4899 , new wolfs: 96
# timestep: 121 , rabbits: 60007 , wolfs: 667 , rabbits eaten: 195  wolfs dead: 113
# timestep: 121 , new rabbits: 5454 , new wolfs: 95
# timestep: 122 , rabbits: 65749 , wolfs: 672 , rabbits eaten: 213  wolfs dead: 115
# timestep: 122 , new rabbits: 5939 , new wolfs: 100
# timestep: 123 , rabbits: 72169 , wolfs: 644 , rabbits eaten: 192  wolfs dead: 121
# timestep: 123 , new rabbits: 6587 , new wolfs: 81
# timestep: 124 , rabbits: 79302 , wolfs: 630 , rabbits eaten: 162  wolfs dead: 115
# timestep: 124 , new rabbits: 7287 , new wolfs: 90
# timestep: 125 , rabbits: 86985 , wolfs: 644 , rabbits eaten: 215  wolfs dead: 114
# timestep: 125 , new rabbits: 7879 , new wolfs: 107
# timestep: 126 , rabbits: 95571 , wolfs: 638 , rabbits eaten: 181  wolfs dead: 105
# timestep: 126 , new rabbits: 8751 , new wolfs: 86
# timestep: 127 , rabbits: 104736 , wolfs: 635 , rabbits eaten: 208  wolfs dead: 108
# timestep: 127 , new rabbits: 9354 , new wolfs: 91
# timestep: 128 , rabbits: 114890 , wolfs: 634 , rabbits eaten: 182  wolfs dead: 106
# timestep: 128 , new rabbits: 10323 , new wolfs: 97
# timestep: 129 , rabbits: 126129 , wolfs: 631 , rabbits eaten: 158  wolfs dead: 97
# timestep: 129 , new rabbits: 11386 , new wolfs: 81
# timestep: 130 , rabbits: 138434 , wolfs: 618 , rabbits eaten: 160  wolfs dead: 96
# timestep: 130 , new rabbits: 12443 , new wolfs: 74
# timestep: 131 , rabbits: 152066 , wolfs: 621 , rabbits eaten: 176  wolfs dead: 101
# timestep: 131 , new rabbits: 13785 , new wolfs: 87
# timestep: 132 , rabbits: 167173 , wolfs: 620 , rabbits eaten: 184  wolfs dead: 102
# timestep: 132 , new rabbits: 15276 , new wolfs: 83
# timestep: 133 , rabbits: 183416 , wolfs: 597 , rabbits eaten: 150  wolfs dead: 108
# timestep: 133 , new rabbits: 16384 , new wolfs: 71
# timestep: 134 , rabbits: 201496 , wolfs: 588 , rabbits eaten: 130  wolfs dead: 89
# timestep: 134 , new rabbits: 18199 , new wolfs: 73
# timestep: 135 , rabbits: 221489 , wolfs: 581 , rabbits eaten: 143  wolfs dead: 92
# timestep: 135 , new rabbits: 20125 , new wolfs: 75
# timestep: 136 , rabbits: 243598 , wolfs: 561 , rabbits eaten: 131  wolfs dead: 95
# timestep: 136 , new rabbits: 22229 , new wolfs: 68
# timestep: 137 , rabbits: 267905 , wolfs: 552 , rabbits eaten: 143  wolfs dead: 93
# timestep: 137 , new rabbits: 24438 , new wolfs: 72
# timestep: 138 , rabbits: 294696 , wolfs: 538 , rabbits eaten: 140  wolfs dead: 95
# timestep: 138 , new rabbits: 26912 , new wolfs: 67
# timestep: 139 , rabbits: 323890 , wolfs: 539 , rabbits eaten: 130  wolfs dead: 90
# timestep: 139 , new rabbits: 29314 , new wolfs: 79
# timestep: 140 , rabbits: 355812 , wolfs: 529 , rabbits eaten: 165  wolfs dead: 95
# timestep: 140 , new rabbits: 32072 , new wolfs: 69
# timestep: 141 , rabbits: 391250 , wolfs: 538 , rabbits eaten: 152  wolfs dead: 74
# timestep: 141 , new rabbits: 35575 , new wolfs: 76
# timestep: 142 , rabbits: 430157 , wolfs: 528 , rabbits eaten: 124  wolfs dead: 88
# timestep: 142 , new rabbits: 39022 , new wolfs: 63
# timestep: 143 , rabbits: 472925 , wolfs: 511 , rabbits eaten: 140  wolfs dead: 83
# timestep: 143 , new rabbits: 42895 , new wolfs: 56
# timestep: 144 , rabbits: 520233 , wolfs: 483 , rabbits eaten: 117  wolfs dead: 91
# timestep: 144 , new rabbits: 47422 , new wolfs: 55
# timestep: 145 , rabbits: 572112 , wolfs: 475 , rabbits eaten: 146  wolfs dead: 72
# timestep: 145 , new rabbits: 52008 , new wolfs: 56
# timestep: 146 , rabbits: 629201 , wolfs: 473 , rabbits eaten: 141  wolfs dead: 76
# timestep: 146 , new rabbits: 57217 , new wolfs: 61
# timestep: 147 , rabbits: 692165 , wolfs: 486 , rabbits eaten: 164  wolfs dead: 76
# timestep: 147 , new rabbits: 63111 , new wolfs: 78
# timestep: 148 , rabbits: 761035 , wolfs: 498 , rabbits eaten: 161  wolfs dead: 72
# timestep: 148 , new rabbits: 69014 , new wolfs: 74
# timestep: 149 , rabbits: 836928 , wolfs: 474 , rabbits eaten: 144  wolfs dead: 104
# timestep: 149 , new rabbits: 76019 , new wolfs: 66

# %% [markdown]
# # Plotting

# %%
N_over_time = np.sum(N,axis=4)
N_over_time_total = np.sum(N_over_time,axis=0)
N_over_time_total = np.sum(N_over_time_total,axis=0)
N_median_over_time = (np.percentile(N_over_time,50,axis=0))[0,:,:]

# %%
fig,axes = plt.subplots(1,1,figsize=(20,10))
t = np.linspace(0, 15,  150)    
for i in range(nx):
    for j in range(ny):
        axes.plot(t,N_over_time[i,j,0],'b',alpha=0.2)
        axes.plot(t,N_over_time[i,j,1],'orange',alpha=0.2)
#plt.plot(t,N_over_time_total[0]/nx/ny,'b',linewidth=3)
#plt.plot(t,N_over_time_total[1]/nx/ny,'orange',linewidth=3)
plt.plot(t,N_median_over_time[0,:],'b',linewidth=3)
plt.plot(t,N_median_over_time[1,:],'orange',linewidth=3)
plt.yscale('log')
plt.ylim([0.5,1000])
# Out:
# (0.5, 1000)

# %% [markdown]
# # Analytical version taken from scipy cookbook

# %% [markdown]
# du/dt =  a*u -   b*u*v
# dv/dt = -c*v + d*b*u*v

# %% [markdown]
# *  u: number of preys (for example, rabbits)
#
# *  v: number of predators (for example, foxes)
#
# * a, b, c, d are constant parameters defining the behavior of the population:
#
#   + a is the natural growing rate of rabbits, when there's no fox
#
#   + b is the natural dying rate of rabbits, due to predation
#
#   + c is the natural dying rate of fox, when there's no rabbit
#
#   + d is the factor describing how many caught rabbits let create a new fox

# %% [markdown]
# We will use X=[u, v] to describe the state of both populations.
#
# Definition of the equations:

# %%
def dX_dt(X, t=0):
    """ Return the growth rate of cat and rat populations. """
    return np.array([ a*X[0] -   b*X[0]*X[1] ,
                  -c*X[1] + d*b*X[0]*X[1] ])

# %%
#!python
from scipy import integrate
t = np.linspace(0, 15,  1500)              # time
t_ana = t
X0 = np.array([50, 15])                     # initials conditions: 10 rabbits and 5 foxes
X0 = np.array([64, 16])                     # initials conditions: 10 rabbits and 5 foxes
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']                     # >>> 'Integration successful.'
rats, cats = X.T

# %% [markdown]
# # plotting both

# %%
fig,axes = plt.subplots(1,1,figsize=(10,5))
t = np.linspace(0, 15,  150)    
for i in range(1,nx):
    for j in range(ny):
        axes.plot(t,N_over_time[i,j,0],'b'     ,alpha=0.2,linewidth=1.5)
        axes.plot(t,N_over_time[i,j,1],'orange',alpha=0.2,linewidth=1.5)
axes.plot(t,N_over_time[0,0,0],'b'             ,alpha=0.2,linewidth=1.5,label='Prey discrete')
axes.plot(t,N_over_time[0,0,1],'orange'        ,alpha=0.2,linewidth=1.5,label='Pred discrete')
plt.plot(t,N_median_over_time[0,:],'w',linewidth=4)
plt.plot(t,N_median_over_time[1,:],'w',linewidth=4)
plt.plot(t,N_median_over_time[0,:],'b'     ,linewidth=3,label='Ensemble median')
plt.plot(t,N_median_over_time[1,:],'orange',linewidth=3,label='Ensemble median')
plt.yscale('log')
plt.ylim([0.5,4000])
plt.xlim([0.,15])
plt.xlabel('time')
plt.ylabel('number')


plt.plot(t_ana, rats, 'w',   linewidth=5)
plt.plot(t_ana, cats  , 'w', linewidth=5)
plt.plot(t_ana, rats, 'b', linewidth=3  ,linestyle='--',label='Prey continuous')
plt.plot(t_ana, cats  , 'orange', linewidth=3  ,linestyle='--',label='Pred continuous')
plt.legend(ncol=3,loc='upper center')


#axes.set_xticks(siz[[0,1,2,3,5,9]])
#axes.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
#axes.set_yticks([int(1),2,3,4,8,16,2**5,4**3,2**7,4**4,2**9])
axes.set_yticks([int(1),2,3,4,8,16,2**5,4**3,4**4,2**10])
axes.get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())


#fig.savefig('fig/lotka_voltera_digital_vs_analog_0515.pdf',bbox_inches='tight')

# %%
fig,axes = plt.subplots(1,2,figsize=(8,4),sharey=True,sharex=True)
t = np.linspace(0, 15,  150)    
for i in range(1,nx):
    for j in range(ny):
        axes[0].plot(t,N_over_time[i,j,0],'b'     ,alpha=0.2,linewidth=1.5)
        axes[1].plot(t,N_over_time[i,j,1],'orange',alpha=0.3,linewidth=1.5)
axes[0].plot(t,N_over_time[0,0,0],'b'             ,alpha=0.2,linewidth=1.5,label='discrete')
axes[1].plot(t,N_over_time[0,0,1],'orange'        ,alpha=0.3,linewidth=1.5,label='discrete')
axes[0].plot(t,N_median_over_time[0,:],'w',linewidth=4)
axes[1].plot(t,N_median_over_time[1,:],'w',linewidth=4)
axes[0].plot(t,N_median_over_time[0,:],'b'     ,linewidth=3,label='ensemble median')
axes[1].plot(t,N_median_over_time[1,:],'orange',linewidth=3,label='ensemble median')
axes[0].set_yscale('log')
axes[0].set_ylim([0.75,1024])
axes[0].set_xlim([0.,15])
axes[0].set_xlabel('time')
axes[1].set_xlabel('time')
axes[0].set_ylabel('number')

axes[0].set_title('Prey')
axes[1].set_title('Predator')

axes[0].plot(t_ana, rats, 'w',   linewidth=5)
axes[1].plot(t_ana, cats  , 'w', linewidth=5)
axes[0].plot(t_ana, rats, 'b', linewidth=3  ,linestyle='--'       ,label='continuous')
axes[1].plot(t_ana, cats  , 'orange', linewidth=3  ,linestyle='--',label='continuous')
axes[1].legend(ncol=1,loc='upper center')


#axes.set_xticks(siz[[0,1,2,3,5,9]])
#axes.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
#axes.set_yticks([int(1),2,3,4,8,16,2**5,4**3,2**7,4**4,2**9])
axes[0].set_yticks([int(1),2,4,8,16,2**5,4**3,4**4,2**10])
axes[0].get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
axes[0].set_xticks([int(0),3,6,9,12])

plt.subplots_adjust(wspace=0.02)

# %%
fig.savefig('fig/predprey_0520.pdf',bbox_inches='tight')

# %%
# Total amount over all cells

N_over_time = np.sum(N,axis=4)
plt.plot(N_over_time[0,0,0,:],'b')
plt.plot(N_over_time[0,0,1,:],'orange')
plt.yscale('log')
#plt.plot(N_over_time_total[1],'orange')

# %% [markdown]
# # lets look at age distribution

# %%
#only looking up to a specific timestep
t_max = 50
N_by_age = np.sum(N[:,:,:,:t_max,:],axis=3)
N_by_age = np.sum(N_by_age,axis=0)
N_by_age = np.sum(N_by_age,axis=0)

# %%
fig, ax = plt.subplots(1,1,figsize=(10,5))
ax.plot(N_by_age[0,:],'b',label='prey')
ax.plot(N_by_age[1,:],'orange',label='predator')
plt.legend()
ax.set_yscale('log')
ax.set_xlabel('age of objects')
ax.set_ylabel('number')
# Out:
# Text(0, 0.5, 'number')

# %% [markdown]
# ## look at single timestep

# %%
#only looking up to a specific timestep
t_max = 100
N_by_age = N[:,:,:,t_max,:]
N_by_age = np.sum(N_by_age,axis=0)
N_by_age = np.sum(N_by_age,axis=0)

# %%
fig, ax = plt.subplots(1,1,figsize=(10,5))
ax.plot(N_by_age[0,:],'b',label='prey')
ax.plot(N_by_age[1,:],'orange',label='predator')
plt.legend()
ax.set_yscale('log')
ax.set_xlabel('age of objects')
ax.set_ylabel('number')
# Out:
# Text(0, 0.5, 'number')
